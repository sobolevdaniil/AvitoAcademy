# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Теория-вероятностей-и-математическая-статистика.-БДЗ." data-toc-modified-id="Теория-вероятностей-и-математическая-статистика.-БДЗ.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Теория вероятностей и математическая статистика. БДЗ.</a></span><ul class="toc-item"><li><span><a href="#Импорт-необходимых-библиотек" data-toc-modified-id="Импорт-необходимых-библиотек-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импорт необходимых библиотек</a></span></li><li><span><a href="#Задача-1.-Визуализация-ЗБЧ" data-toc-modified-id="Задача-1.-Визуализация-ЗБЧ-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Задача 1. Визуализация ЗБЧ</a></span><ul class="toc-item"><li><span><a href="#Стандартное-нормальное-распределение" data-toc-modified-id="Стандартное-нормальное-распределение-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Стандартное нормальное распределение</a></span></li><li><span><a href="#Экспоненциальное-распределение" data-toc-modified-id="Экспоненциальное-распределение-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Экспоненциальное распределение</a></span></li><li><span><a href="#Распределение-Пуассона" data-toc-modified-id="Распределение-Пуассона-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Распределение Пуассона</a></span></li></ul></li><li><span><a href="#Задача-2.-Визуализация-Закона-Устойчивости-Относительных-Частот." data-toc-modified-id="Задача-2.-Визуализация-Закона-Устойчивости-Относительных-Частот.-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Задача 2. Визуализация Закона Устойчивости Относительных Частот.</a></span><ul class="toc-item"><li><span><a href="#Бросание-кубиков" data-toc-modified-id="Бросание-кубиков-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Бросание кубиков</a></span></li><li><span><a href="#Вытягивание-карт" data-toc-modified-id="Вытягивание-карт-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Вытягивание карт</a></span></li></ul></li><li><span><a href="#Задача-3.-Визуализация-кл.-ЦПТ." data-toc-modified-id="Задача-3.-Визуализация-кл.-ЦПТ.-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Задача 3. Визуализация кл. ЦПТ.</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-на-экспоненциальное-распределение:" data-toc-modified-id="Посмотрим-на-экспоненциальное-распределение:-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Посмотрим на экспоненциальное распределение:</a></span><ul class="toc-item"><li><span><a href="#n-=-10" data-toc-modified-id="n-=-10-1.4.1.1"><span class="toc-item-num">1.4.1.1&nbsp;&nbsp;</span>n = 10</a></span></li><li><span><a href="#n-=-100" data-toc-modified-id="n-=-100-1.4.1.2"><span class="toc-item-num">1.4.1.2&nbsp;&nbsp;</span>n = 100</a></span></li><li><span><a href="#n-=-500" data-toc-modified-id="n-=-500-1.4.1.3"><span class="toc-item-num">1.4.1.3&nbsp;&nbsp;</span>n = 500</a></span></li></ul></li></ul></li><li><span><a href="#Задача-4.-Элементы-математической-статистики." data-toc-modified-id="Задача-4.-Элементы-математической-статистики.-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Задача 4. Элементы математической статистики.</a></span><ul class="toc-item"><li><span><a href="#Оценка-математического-ожидания" data-toc-modified-id="Оценка-математического-ожидания-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Оценка математического ожидания</a></span></li><li><span><a href="#Оценка-дисперсии" data-toc-modified-id="Оценка-дисперсии-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Оценка дисперсии</a></span></li><li><span><a href="#Построение-эмпирической-функции-распределения-(без-учета-плотности)" data-toc-modified-id="Построение-эмпирической-функции-распределения-(без-учета-плотности)-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Построение эмпирической функции распределения (без учета плотности)</a></span></li><li><span><a href="#Построение-кривых-на-одном-графике" data-toc-modified-id="Построение-кривых-на-одном-графике-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>Построение кривых на одном графике</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Теория вероятностей и математическая статистика. БДЗ.

# %% [markdown]
# ## Импорт необходимых библиотек

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm, expon, poisson

from sklearn.utils import shuffle

import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tqdm

# убираем уведомления о предупреждениях
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Задача 1. Визуализация ЗБЧ

# %% [markdown]
# По одной из формулировок закона больших чисел, для СВ $\xi$ с $M(\xi) = 𝑎 < +\infty$ выполнено:
#  $\langle 𝜉𝑛 \rangle \rightarrow 𝑎$, где $\langle 𝜉𝑛 \rangle = \frac{1}{n} \sum_{k=1}^n \xi_k  $

# %% [markdown]
# Пусть:
#
# - $N$ - количество наборов случайных величин
# - $n$ - количество элементов в наборе <br>
# - cимволом $j$ будем обозначать номер выборки

# %%
def plot(N: int, means: list, mean: float, label1: str, label2: str) -> None:
    """
        Функция для построения графика зависимости отклонения от среднего значения
        - N - количество выборок
        - means - список со значением для каждой из выборок
        - mean - истинное среднне значение       
    """
    plt.figure(figsize=(15, 30))
    plt.title('Отклонения от среднего значения', fontsize=12)
    plt.scatter(means, range(N), linewidth=2, label = label1)
    plt.plot([mean for i in range(N)], range(N), linestyle='--', color='g', label = label2)

    plt.xlabel('Отклонение', fontsize=12)
    plt.ylabel('Номер выборки', fontsize=12)
    plt.legend(fontsize=12)
    plt.show()

# %%
def density_plot(means: list) -> None:
    """
        Функция для построения графика плотности распределения
        - means - список с аггрегированными значениями выборок
    """
    plt.figure(figsize=(10, 5))
    plt.title('Распределение средних значений', fontsize=12)
    sns.distplot(means, color='b', label='Эмпирическое распределение')
    
    plt.xlabel('X', fontsize=12)
    plt.ylabel('Плотность', fontsize=12)
    plt.legend(fontsize=12)
    plt.show()

# %%
def find_means(N: int, n: int, generator) -> list:
    """
        Функция получит список со средними значениями
        - N - количество выборок
        - n - количество значений в каждой выборке
    """
    means = []
    for j in range(N):
        collection = generator()
        mean = collection.mean()
        means.append(mean)
    return means

# %%
def norm_generator(n: int) -> np.array:
    return np.random.randn(n)

# %%
def expon_generator(L: float, n: int) -> np.array:
    return np.random.exponential(1/L, n)

# %%
def poisson_generator(L: float, n: int) -> np.array:
    return np.random.poisson(1/L, n)

# %% [markdown]
# ### Стандартное нормальное распределение

# %% [markdown]
# - Математическое ожидание - ноль
# - Дисперсия - еденица
#
# Среднее значение должно стремится к метматическому ожиданию, то есть к нулю

# %%
means = find_means(400, 10_000, lambda: norm_generator(10_000))
plot(400, means, 0, 'Среднне j-ой выборки', 'Мат ожидание распределения')

# %%
density_plot(means)

# %% [markdown]
# Также было бы интересно посмотреть на то, как зависит отклонение от среднего при различных значениях n.
#
# В теории чем больше выборка, тем меньше должно быть отклонение от истинного среднего.

# %%
def convergence_plot_norm(n_max: int, true_mean: float) -> None:
    """
        Функция для построения зависимости количества значений в выборке 
        от отклонения среднего выборки от истинного среднего при нормальном распределении
        
        - n - максимальное количество элементов в выборке
        - true_mean - истинное среднее
    """
    plt.figure(figsize=(20, 20))
    
    for n in range(1, n_max):
        collection = norm_generator(n)
        mean = collection.mean()
        plt.plot(n, mean, '_', alpha = 1, linewidth=2)
        
    plt.plot(range(n), [true_mean for i in range(n)], linestyle='--', color='b', label = 'Истинное среднее', linewidth=3)

    plt.xlabel('Количество элементов в выборке', fontsize=12)
    plt.ylabel('Отклонение', fontsize=12)
    plt.ylim([true_mean - 0.3, true_mean + 0.3])
    plt.legend(fontsize=12)
    plt.show()

# %%
convergence_plot_norm(10_000, 0)

# %% [markdown]
# **Вывод:**<br>
# - Из графика видно, что значения отклонились на 2-3% от среднего значения. Что может потдверждать теорию о том, что среднее стремится к мат ожиданию. Если бы мы взяли $n = 100 000$, то отклонение было бы меньше. И в пределе при $n \rightarrow \infty$стремилось бы к 0.
#
# - Также можно заметить, если увеличивать количество выборок, то распределенеие плотности будет стремиться к нормальному
#
# - Отклонение от среднего выборки тем меньше, чем больше значений в этой выборке

# %% [markdown]
# ### Экспоненциальное распределение

# %% [markdown]
# Примем парметр $\lambda$ равный еденице, тогда:
#
# - Математическое ожидание - 1/$\lambda$ = 1
# - Дисперсия - 1/$\lambda^2$ = 1

# %%
means = find_means(400, 10_000, lambda: expon_generator(1, 10_000))
plot(400, means, 1, 'Среднне j-ой выборки', 'Мат ожидание распределения')

# %%
density_plot(means)

# %%
def convergence_plot_expon(n_max: int, true_mean: float, L: float) -> None:
    """
        Функция для построения зависимости количества значений в выборке 
        от отклонения от истинного среднего при экспоненциальном распределении
        
        - n - максимальное количество элементов в выборке
        - true_mean - истинное среднее
        - L - параметр лямбда у экспоненциального распределения
    """
    plt.figure(figsize=(20, 20))
    
    for n in range(1, n_max):
        collection = expon_generator(L, n)
        mean = collection.mean()
        plt.plot(n, mean, '_', alpha = 1, linewidth=2)
        
    plt.plot(range(n), [true_mean for i in range(n)], linestyle='--', color='b', label = 'Истинное среднее', linewidth=3)

    plt.xlabel('Количество элементов в выборке', fontsize=12)
    plt.ylabel('Отклонение', fontsize=12)
    plt.ylim([true_mean - 0.3, true_mean + 0.3])
    plt.legend(fontsize=12)
    plt.show()

# %%
convergence_plot_expon(10_000, 1, 1)

# %% [markdown]
# ### Распределение Пуассона

# %% [markdown]
# Примем парметр $\lambda$ равный 10, тогда:
#
# - Математическое ожидание - 1/$\lambda$ = 1/10
# - Дисперсия - 1/$\lambda$ = 1/10

# %%
means = find_means(400, 10_000, lambda: poisson_generator(10, 10_000))
plot(400, means, 1/10, 'Среднне j-ой выборки', 'Мат ожидание распределения')

# %%
density_plot(means)

# %%
def convergence_plot_expon(n_max: int, true_mean: float, L: float) -> None:
    """
        Функция для построения зависимости количества значений в выборке 
        от отклонения от истинного среднего при экспоненциальном распределении
        
        - n - максимальное количество элементов в выборке
        - true_mean - истинное среднее
        - L - параметр лямбда у экспоненциального распределения
    """
    plt.figure(figsize=(20, 20))
    
    for n in range(1, n_max):
        collection = expon_generator(L, n)
        mean = collection.mean()
        plt.plot(n, mean, '_', alpha = 1, linewidth=2)
        
    plt.plot(range(n), [true_mean for i in range(n)], linestyle='--', color='b', label = 'Истинное среднее', linewidth=3)

    plt.xlabel('Количество элементов в выборке', fontsize=12)
    plt.ylabel('Отклонение', fontsize=12)
    plt.ylim([true_mean - 0.03, true_mean + 0.03])
    plt.legend(fontsize=12)
    plt.show()

# %%
convergence_plot_expon(10_000, 1/10, 10)

# %% [markdown]
# Выводы относительные Пуассонвского и Экспоненциального распределений аналогичны.

# %% [markdown]
# ## Задача 2. Визуализация Закона Устойчивости Относительных Частот.

# %% [markdown]
# Пусть $\mu_n(A) = \frac {n(A)} {n}$ - относительная частота наступления события A в n опытах, где $A(n)$ - количество опытов, в которых событие А наступило. Тогда $\mu_n \rightarrow P(A)$
#
# В качествее события А:
# - Выпадение 7 очков при бросании 2-ух костей
# - Вытягивание 5 карт из колоды 52 карты (4 масти, 13 номиналов) так, что среди их окажутся два туза, два короля и одна семерка.

# %% [markdown]
# Пусть:
# - $N$ - количество наборов, $j$ - номер набора
# - $n$ - количество элементарных исходов в каждом наборе

# %% [markdown]
# ### Бросание кубиков

# %% [markdown]
# Найдем теоретически значение $P(A)$:
#
# $P(A) = \frac m n$, где
# - m - количество благоприятных исходов
# - n - количество всевозможных исходов
#
# Благоприятные исходы: (1,6) (6,1) (2,5) (5,2) (3,4) (4,3) <br>
# Их количество: 6
#
# Всевозможные исходы: значение на каждом кубике выпадает независимо от друг друга, то есть всего исходов 6*6
#
# Тогда $P(A) = \frac 6 {36} = \frac 1 6 \approx 0.167$

# %%
def find_selection(N: int, n: int, point: int) -> list:
    """
        Функция получает список со значением вероятности события для каждой выборки
        - N - количество выборок
        - n - количество значений в выборке
        - point - событие
    """
    selection = []
    for j in range(N):
        count = 0
        for i in range(n):
            a = np.random.randint(1, 7)
            b = np.random.randint(1, 7)
            if (a + b) == point:
                count += 1
        selection.append(count/n)
    return selection

# %%
selection = find_selection(400, 500, 7)
plot(400, selection, 1/6, 'Вероятность в j-ой выборке', 'Истинная вероятность')

# %%
density_plot(selection)

# %% [markdown]
# **Вывод:**
#
# - Проделанный эксперимент подтверждает теоретические свойства. При стремлении n к бесконечности, значения каждой выборки будут стремится к истинной вероятности.

# %% [markdown]
# ### Вытягивание карт

# %% [markdown]
# Найдем теоретически значение $P(A)$:
#
# $P(A) = \frac m n$, где
# - m - количество благоприятных исходов
# - n - количество всевозможных исходов
#
# Количество способов извлечь два туза: $C_{4}^{2} = \frac {4!} {2!2!} = 6$ <br>
# Количество способов извлечь два короля: $C_{4}^{2} = \frac {4!} {2!2!} = 6$ <br>
# Количество способов извлечь одну семперку: $C_{4}^{1} = \frac {4!} {3!1!} = 4$
#
# Количество способов извлечь пять карт из пятидесяти двух: $C_{52}^{5} = \frac {52!} {47!5!} = \alpha$
#
# Тогда $P(A) = \frac {6*6*4} \alpha$

# %% [markdown]
# - Всего тринадцать номиналов, пусть числа от одного до тринадцати отвечают им
# - Тогда нам нужно: два раза 13, два раза 12 и один раз 6

# %%
def find_collection(N: int, n: int, points: list) -> list:
    """
        Функция получает список со значением вероятности события для каждой выборки
        - N - количество выборок
        - n - количество значений в выборке
        - points - список с благоприятными значениями
    """
    collection = []
    for j in tqdm(range(N)):
        count = 0 
        for i in range(n):
            cards = [
                np.random.randint(1, 14),
                np.random.randint(1, 14),
                np.random.randint(1, 14),
                np.random.randint(1, 14),
                np.random.randint(1, 14),
            ]
            
            for point in points:
                if point in cards:
                    cards.remove(point)
            if cards == []:
                count += 1
        collection.append(count/n)
    return collection

# %%
collection = find_collection(400, 100_000, [13, 13, 12, 12, 6])
# Out:
# 100%|█████████████████████████████████████████| 400/400 [07:41<00:00,  1.15s/it]

# %%
plot(
    400, 
    collection, 
    6*6*4*np.math.factorial(47)*np.math.factorial(5) / np.math.factorial(52), 
    'Вероятность в j-ой выборке', 
    'Истинная вероятность'
)

# %%
density_plot(collection)

# %% [markdown]
# **Вывод:**
#
# - Следстивя из данного эксперимента в точности не могут подтверждать теорию, так как разброс значений очень большой и вероятность получения нашего исхода очень низкая. Поэтому результаты были бы корректны только при больших n.
#
# - По графику плотности можно подумать, что всё ок, так как величина распределилась близка к нормальному. Но распределение получилось вокруг не истинного значения вероятности! А может я неправильно высчитал истинное :)

# %% [markdown]
# ## Задача 3. Визуализация кл. ЦПТ.

# %% [markdown]
# Пусть $\xi_1, ..., \xi_n$ &mdash; **независимо** одинаково распределенные случайные величины, у которых сущестуют мат. ожидание и дисперсия: $E [\xi_i] = \mu < \infty$ и $Var[\xi_i] = \sigma^2 < \infty$.
# Тогда $\sqrt{n}\dfrac{\overline \xi - \mu}{\sqrt{\sigma^2}}$ [сходится по распределению](https://en.wikipedia.org/wiki/Convergence_in_distribution) к $\mathcal{N}(0, 1)$,
# где $\overline \xi -$ среднее арифметическое выборки

# %% [markdown]
# ### Посмотрим на экспоненциальное распределение:

# %% [markdown]
# Примем парметр $\lambda$ равный 10, тогда:
#
# - Математическое ожидание - 1/$\lambda$ = 1/10
# - Дисперсия - 1/$\lambda^2$ = 1/100

# %%
def find_clt_values(N:int, sample_generator, expected_value:float, variance:float) -> list:
    """
        Функция получает список со значениями статистики ЦПТ
        Параметры:
            - sample_generator: функция-генератор выборки. Не принимает ничего на вход
            - expected_value: мат. ожидание выборки
            - variance: дисперсия выборки
    """
    clt_sample = []
    for _ in range(N):
        # генерируем N раз выборку
        sample = sample_generator()

        # считаем статистику из ЦПТ
        sample_size = len(sample)
        statistic = np.sqrt(sample_size) * (np.mean(sample) - expected_value) / np.sqrt(variance)

        #сохраняем
        clt_sample.append(statistic)
    return clt_sample

# %%
def visualize_relation(N:int, clt_sample: list, label1: str) -> None:
    """
        Функция для построения графика зависимости отклонения от среднего значения
        - N - количество выборок
        - means - список со значением для каждой из выборок
        - mean - истинное среднне значение       
    """
    plt.figure(figsize=(15, 30))
    plt.title('Отклонения от среднего значения', fontsize=12)
    plt.scatter(clt_sample, range(N), linewidth=2, label = label1)

    plt.xlabel('Статистика', fontsize=12)
    plt.ylabel('Номер выборки', fontsize=12)
    plt.legend(fontsize=12)
    plt.show()

# %%
def visualize_CLT(clt_sample: np.array) -> None:
    """
        Функция-визуализатор ЦПТ. Строит:
            - гисторгамму статистики ЦПТ,
            - эмпирическую плотность,
            - плотность нормального распределения.
        - clt_sample - значения статистики ЦПТ.
    """

    x = np.linspace(-4, 4, 1000)
    plt.figure(figsize=(10, 5))
    plt.title('Распределение средних значений', fontsize=12)
    sns.distplot(clt_sample, color = 'b', label='Эмпирическое распределение')
    plt.plot(x, norm().pdf(x), label='$\mathcal{N}(0, 1)$')
    
    plt.xlabel('X', fontsize=12)
    plt.ylabel('Плотность', fontsize=12)
    plt.legend(fontsize=12)
    plt.show()

# %%
clt_sample = find_clt_values (
    400,
    lambda: expon_generator(10, 5000), 
    expected_value=1/10, variance=(1/10) ** 2
)

# %%
visualize_relation(400, clt_sample, 'Статистика j-ой выборки')

# %% [markdown]
# - Из графика видно, что можно найти такую статистику, что плотность её будет больше и при этом можно заметить, что при отклонении от неё количество значений будут убывать.
# - В теории - статистика должна стремится к стандартному нормальному распределению, что в принципе не отрицает наш график.
# - Чтобы убедиться в этом, посомтрим на график плотности распределению нашей статистики.

# %%
visualize_CLT(clt_sample)

# %% [markdown]
# Очень близко к стандартному нормальному распределению!

# %% [markdown]
# - Хотелось бы посмотреть, как ведет себя статистика при изменении количества элементов в выборках.
# - Для этого возьмем $n = 10, 100, 500$ и построим гистограммы плотности в каждом из случаев.

# %% [markdown]
# #### n = 10

# %%
clt_sample = find_clt_values (
    400,
    lambda: expon_generator(10, 10), 
    expected_value=1/10, variance=(1/10) ** 2
)

visualize_CLT(clt_sample)

# %% [markdown]
# #### n = 100

# %%
clt_sample = find_clt_values (
    400,
    lambda: expon_generator(10, 100), 
    expected_value=1/10, variance=(1/10) ** 2
)

visualize_CLT(clt_sample)

# %% [markdown]
# #### n = 500

# %%
clt_sample = find_clt_values (
    400,
    lambda: expon_generator(10, 500), 
    expected_value=1/10, variance=(1/10) ** 2
)

visualize_CLT(clt_sample)

# %% [markdown]
# **Вывод:**
# - Можно сделать вывод о том, что чем меньше значений в выборке, тем хуже статистика сходится к стандартному нормальному распределению!

# %% [markdown]
# *Дополнение*
#
# Случайные величины могут быть слабо зависимы друг от друга и слегка по-разному распределены. Центральная пределеньная теорма все еще будет [верна](https://en.wikipedia.org/wiki/Stable_distribution#A_generalized_central_limit_theorem).

# %% [markdown]
# ## Задача 4. Элементы математической статистики.

# %% [markdown]
# Оценки параметров.
#
#
# -  В математической статистике оценкой некоторого параметра $\theta$ связанного со случайной  выборкой $(X_1, X_2, ..., X_n)$, называется произвольная функция от выборки $\widehat \theta = \widehat \theta_n = \theta(𝑋_1, 𝑋_2, ... , 𝑋_n).$
# - Оценка праметра $\theta$ называется <u>несмещенной</u>, если $M\widehat\theta_n = \theta$
# - Оценка $\theta$ называется <u>состоятельной</u>, если $\forall \varepsilon > 0 \lim\limits_{n \to +\infty} \{P|\widehat\theta_n - \theta| < \varepsilon\} = 1$, <br>
# то есть при увеличении объема выборки вероятность больших отклонений оценки от оцениваемого параметра стремится к нулю.

# %% [markdown]
# Согласно методу моментов, если требуется оценить величину $a_j = MX_{1}^{j}$ - момент порядка j, то качестве оценки следует использовать выборочный моент порядка j:
#
# $$\widehat a_j = \frac 1 n \sum_{k = 1}^{n} X_{k}^{j}$$

# %% [markdown]
# Если же нужно оценить величину $b_j = M(X_1 - MX_1)^j$ - центральный момент порядка j, то оценкой служит центральный выборочный момент порядка j, задаваемый равенством:
# $$\widehat b_j = \frac 1 n \sum_{k=1}^n (X_k - \overline X)^j,$$
# где $\overline X$ - среднее арифметическое выборки

# %% [markdown]
# - Выборочный момент $\widehat a_j$ является <u> несмещенной и состоятельной оценкой.</u>
# - Центральный выборочный момент $\widehat b_j$ для $j \geq 2$ является <u>смещенной</u> и при этом <u>состоятельной оценкой.</u>
# - Для оценки математического ожидания используют выборочный элемент $\widehat a_1$
# - Для оценки дисперсии $\sigma^2 = b_2$
#     - При малых $n$ используют несмещенную оценку $S^2 = \frac {n} {n-1} \widehat\sigma^2 = \frac n {n-1} \widehat b_2$
#     - При больших $n$ можно использовать выборочный $\widehat \sigma^2 = \widehat b_2$, так как её смещение неыелико.

# %% [markdown]
# <u>**Эмпирическая фугкция распределения:**</u> - случайная величина, определяемая равенством:
#
# $$F_n^*(x) = \frac 1 n \sum_{k=1}^{n}\chi \{X_k < x\} = \frac 1 n \nu_n(x),$$
#
# где $\nu_n(x) =$ (число тех $X_k$ среди $X_1, X_2, X_3 ..., X_n$, которые меньше $x)$;
# $\chi(A)$ - индикатор события.
#
# Можно показать, что $F_n^*(x)$ является <u>несмещенной и состоятельной</u> оценкой функции распределения $F(x)$ в каждой очке $x \in (-\infty;\infty).$

# %% [markdown]
# Извлечем данные, возьмем 12 вариант.

# %%
data = pd.read_csv('/Users/daniilsobolev/Desktop/Аналитика/Статистика/БДЗ/Task4.csv')
var = '12'
data = data[var]

# %%
data.head()
# Out:
# 0    18673.0
# 1      933.0
# 2    78488.0
# 3    13434.0
# 4     1703.0
# Name: 12, dtype: float64

# %%
print(f'Количество данных в выборке: {len(data)}')
# Out:
# Количество данных в выборке: 300

# %% [markdown]
# - Данные - это набор случайных величин.
# - Посмотрим на распределение данных.

# %%
density_plot(data)

# %% [markdown]
# Сразу не понятно какое перед нами распределение. Попробуем оценивая параметры: математическое ожидание и дисперсию узнать, какое это распределение, в будущем наложив на гистограмму дополнительные распределения (нормальное, пуассоновское, экспоненциальное) с полученными параметрами.

# %% [markdown]
# ### Оценка математического ожидания

# %% [markdown]
# Нам надо оценить $a_j = MX_{1}^{j}$ - момент порядка $j$, при $j = 1$, тогда воспользуемся следующей формулой:
# $$\widehat a_1 = \frac 1 n \sum_{k = 1}^{n} X_{k}$$

# %%
def plot_sample_means(data, size:int, steps:int) -> None:
    """
        Функция строит график выборочных средних значений
        - steps - количество получаемых средних
        - size - количество значений в кождой подвыборке
    """
    
    means = [data.sample(size).mean() for i in range(steps)]
    
    plt.figure(figsize=(10, 5))
    plt.title('Распределение средних значений', fontsize=12)
    sns.distplot(means, color='b', label='Распределение средних значений')
    
    plt.xlabel('Средниее значение', fontsize=12)
    plt.ylabel('Количество', fontsize=12)
    plt.legend(fontsize=12)
    plt.show()

# %% [markdown]
# Посмотрим на график выборочных средних. В теории выборочные средние должны распределиться нормально вокруг истинного среднего:

# %%
plot_sample_means(data, 30, 1000)

# %% [markdown]
# Из графика видно, что истинное среднее должно получится чуть больше 30 000

# %%
def expectation_estimate(data, size, steps) -> float:
    """
        Функция найдет оценку математического ожидания
    """
    return data.mean()

# %%
print(f'Оценка математического ожидания: {expectation_estimate(data, 30, 1000)}')
# Out:
# Оценка математического ожидания: 31262.98

# %% [markdown]
# ### Оценка дисперсии

# %% [markdown]
# Найдем как смещенную оценку, так и несмещенную.
#
# - Несмещенная:
#
# $$S^2 = \frac {n} {n-1} \widehat\sigma^2 = \frac n {n-1} \widehat b_2 = \frac n {n-1} \frac 1 n \sum_{k=1}^n (X_k - \overline X)^2 = \frac 1 {n-1}  \sum_{k=1}^n (X_k - \overline X)^2$$
#
# - Смещенная:
#
# $$\widehat\sigma^2 = \frac 1 n \sum_{k=1}^n (X_k - \overline X)^2$$

# %%
def dispersion_estimate(data, size:int, steps:int) -> float:
    """
        Функция найдет несмещенную оценку дисперсии 
    """
    return np.var(data)

# %%
print(f'Смещенная оценка дисперсии: {dispersion_estimate(data, 30, 1000)}')
print(f'Несмещенная оценка дисперсии: {dispersion_estimate(data, 30, 1000) * 30 / 29}')
# Out:
# Смещенная оценка дисперсии: 1054002940.8862667
# Несмещенная оценка дисперсии: 1090347869.882345

# %% [markdown]
# ### Построение эмпирической функции распределения (без учета плотности)

# %% [markdown]
# <u>Эмпирическая фугкция распределения:</u>
#
# $$F_n^*(x) = \frac 1 n \sum_{k=1}^{n}\chi \{X_k < x\} = \frac 1 n \nu_n(x),$$
#
# где $\nu_n(x) =$ (число тех $X_k$ среди $X_1, X_2, X_3 ..., X_n$, которые меньше $x)$;
# $\chi(A)$ - индикатор события.

# %%
def plot_empirical_distribution_function(data):
    plt.figure(figsize=(10, 10))
    plt.title('Эмпирическая функция распределения', fontsize=12)
    plt.hist(data, histtype='step', color='b', cumulative=True, bins=len(data))
    plt.xlim([0, 200_000])
    plt.xlabel('Значение x', fontsize=12)
    plt.ylabel('Значение $F(x)$', fontsize=12)
    plt.show()

# %%
plot_empirical_distribution_function(data)

# %% [markdown]
# ### Построение кривых на одном графике

# %% [markdown]
# Построим на одном графике следующие распределения:
# - Гистограмму плотности по значениям выборки
# - Плотность нормального распределения
# - Плотность Пуассоновского распределения
# - Плотность экспоненциального распределения
#
# В качестве параметро плотности возьмем найденные оценки

# %%
def distribution_chart(data):
    mean = expectation_estimate(data, 30, 1000)
    var = dispersion_estimate(data, 30, 1000) ** (1/2)
    
    x = np.linspace(-50_000, 300_000, 1_000_000)
    plt.figure(figsize=(10, 5))
    plt.title('Распределение средних значений', fontsize=12)
    sns.distplot(data, color='b', label='Эмпирическое распределение')    
    plt.plot(x, norm.pdf(x, mean, var), label='Нормальное распределение')
    plt.plot(x, expon.pdf(x, scale=mean), label='Экспоненциальное распределение')
    
    plt.xlabel('X', fontsize=12)
    plt.ylabel('Плотность', fontsize=12)
    plt.legend(fontsize=12)  
    
    plt.show()

# %%
distribution_chart(data)

# %% [markdown]
# Из графика видно, что экспоненциальное распределение лежит почти по ходу исходного распределения, следовательно, скорее всего исходная статистика была распределена экспоненциально.
